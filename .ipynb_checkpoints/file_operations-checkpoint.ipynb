# %% [markdown]
# # Reading and Writing Files

# %% [markdown]
# A file is a sequence of bytes,stored in some filesystem,and accessed by a filename.

# %% [markdown]
# Syntax:
# <font color="orange" face="courier new"><i>open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)</i></font> <br>

# %% [markdown]
# <font color="orange" face="courier new"><i>open()</i></font> returns a<font color="orange" face="courier new"><i> file object </i></font> , and is most commonly used with two arguments: <font color="orange" face="courier new"><i>open(filename, mode)</i></font>

# %% [markdown]
# <ul>
#     <li>The first argument is a string containing the filename.</li>
#     <li>The second argument is another string containing a few characters describing the way in which the file will be used. </li>
#     <li> mode can be:
#     <ul>
#         <li><font color="orange" face="courier new"><i>'r' </i></font>: when the file will only be read</li>
#         <li><font color="orange" face="courier new"><i>'w' </i></font>: for only writing (an existing file with the same name will be erased)</li>
#         <li><font color="orange" face="courier new"><i>'a' </i></font>:  opens the file for appending; any data written to the file is automatically added to the end.</li>
#         <li><font color="orange" face="courier new"><i>'r+' </i></font>:  opens the file for both reading and writing</li>
#           <li>The mode argument is optional;<font color="orange" face="courier new"><i>'r' </i></font>: will be assumed if it’s omitted.</li>
#         </ul>
#     <li> Normally, files are opened in text mode</li>
#     <li> <font color="orange" face="courier new"><i>'b' </i></font> appended to the mode opens the file in binary mode: now the data is read and written in the form of bytes objects.[This mode should be used for all files that don’t contain text.]</li>
# </ul>

# %%
f=open('download.jpg','rb')
for line in f:
    print(line)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x13\x13\x12\x15\x13\x13\x13\x15\x16\x15\x17\x18\x1a\x1a\x16\x18\x18\x18\x1d\x1b\x1a\x1b\x1b\x1a\x1a\x1d\x1a\x1b\x1f \x1a\x18 ("\x18\x1b%\x1b\x1a\x18"1"%)+...\x18\x1f383-7(-.+\x01\n'
# b'\n'
# b'\n'
# b'\x0e\r\x0e\x1b\x10\x10\x1b-% "-+-------/-/--------------------------------------\xff\xc0\x00\x11\x08\x00\xa8\x01,\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x06\x03\x04\x07\x02\x00\x01\x08\xff\xc4\x00B\x10\x00\x01\x03\x02\x04\x03\x05\x06\x05\x03\x03\x02\x05\x05\x00\x00\x01\x02\x03\x11\x00!\x04\x05\x121"AQ\x06\x13aq\x812\x91\xa1\xb1\xc1\xf0\x14#B\xd1\xe1\x07Rbr\x82\xf13\x92Ss\xa2\xb3\xd2\x154Cc\xb2\xff\xc4\x00\x1b\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x04\x01\x02\x05\x00\x06\x07\xff\xc4\x000\x11\x00\x02\x02\x02\x01\x03\x03\x02\x05\x03\x05\x01\x00\x00\x00\x00\x01\x02\x00\x03\x11!\x12\x041A\x13"Qaq\x052\x81\xc1\xf0#\x91\xa13\xb1\xd1\xe1\xf1\x14\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xcfq\x8ci1)>)2\x0f\xd7\xdf\x15\x13\x00\x8a\xbb\x89n\x05UJkX\xd73R\xe3\x0e\xe4\xf9\xa2\x9b)\xd2o\xe3\xb5\xfc\xecG\x9d:\x8c\xd9\xf6BS\x0bno\x1b\x03\xe2\x0fO+mY\x96!1\x10A\x91\xee\xf0\xbf:5\x94v\xad\xf6P\x1aQK\xcc\xff\x00\xe1:5$\x7f\xa4\xee\x83\xfe\x93\x14\xa5\xd4fk\xf4}p\x1ai\xb0\xf6s\xb6)T!\xdb\x7f\x95\xfe4\xe2\xc3\xe9X\x94\x90G\x85`I\xcd[p\x0e\xef\x866J\x8c\x917\x80\xa3\xed\x0f\x03L=\x98\xedb\x9aT\x1b\xa7b\t\xac\xf3\x948=\xa6\x95\x9d%w\xaf:\xb4~<M|\x8a\r\x9b\xf6y\xa7\x84\x90A\xea?cV2\xcc\xe5\xa7\x93(V\xd1#\xa4\xd1 j\xe4\x06\x138\x1b)\x7f \xcc\x87\xb4\x9d\x8d H\x1a\x85\xe4\x81\xb5\xfa\x1b\x8bG\x85g\x19\xb6F\xa4\x19\x02\xd5\xfa\x7f\x11\x87J\xc4(\x03Jy\xefd\xd0\xb4\xaa\x12/t\xc6\xe0\xf4\xe8G\xdc\xf5\xaa)C\xed\x8f\x0e\xa6\xbb\xd7\x8d\xa3\x7f?\xf3?;\x86H\xa284\x11\xd6\x9c3>\xc9\x94%J \x8b\xf0\xf8\xdf\xa1\xbd,\xe1\xf3\x16\x10\xe1l\xa0\xb8A\x83\x06\x12\x08\xde \x89\x8d\xa6w\x9bs\xa7\x96\xe5\xc6L\xce\xea:GS\x88G\x06\r_[\\5S\x15\x9e\xe0\xd0\x07\n'
# b'\xd2\xa9\xd9$(z\x85\x19\x03\xc4M\x11\xc0\xe3\xd9y\x07B\x86\xf1r\x04\xf9I\xbf\xee\x08\xe5FKko3>\xda-C\xdb?m\xca8\x96\xbd\x9f\xf4\x0f\xadV\x14c\x1a\xdc@\xe8\x98\xf5\x13C\x1eL\n'
# b'\'\x0f\x88!a\xecdJz+\xa6\xf1\x9e\x15I\xddD\xc0\xae\x8b\x0e"5\x0br\xa1\xb2FR\xccB,\xe2O9\xaf:\x02\x86\xd5\xd6Z\xca\xdc0\x94\xcf\x95]N\x17\xad\xa9W\xaeiQnu\x02\xaf\r\xe1C1x>\x9di\x9d\xec<s\x15\tD\x0e!#\xc4RD\xf13AG!\x16\x91\x83\xd5"!cn\x8a\xfd\x8dWS\x11\xbd6%\x86M\xcf\t\x9b\x19\xfa\xde\xaacr\x80\xe2\xf5 \xe9\x9b\xc4O\xc8\xd4\x0bw\xb9-\xd3\x92\xb9\x11ei\xaf\xad\xd1,vJ\xe3cR\x94\x88&\x07\xb5>\xed>\x15\x0e\x0b/.(%*\x06H\x1b8"y\xca\x9b\x16\xf1\xa3\xf2\x04E\x00\xc3JN9D\xfbdO\xe2\xdc\x91r\x10Lu(L\xfch\xbe\x1f\xb2\xf8d\xbc\x84\xbd\x8cl\x83\xba[\x82\xa9\xb4\x0b\x93\xbc\x9bi\x93D\xbbE\x98\xe5\x88[\xbf\x90\xe3\xaf\x90RK\x9b\x05F\x91e\xc4\x10z&j\xb9\xde\xa1\x01<L\xcb\x9dB\x94H\x00\x93\xd0\\\xfb\x85F\xa6H0`\x1f1\xf4\xda\x8f\xf6\x9b\x14\xb7\x96\x81\xf8t\xe1\x9b\x03\x81\xb0\x9e\xed&\xfb\xc2\xa3_\x98\x143\t\x87*P\tIT\xf4\x9d\xf9\xf2\xf2\xab\x93\xa8\x00\xbc\x9b\x10\x8e_\x84\x86\x9c<\x8c\x0fPG\xd2\xad\xb2\xd7\xe5\xa7\xca\x99\xc6\x01\xd6\xb0N1\x88kD\x8e\xf5\x92@\xd5)\x12D\x8d\xc1F\xab\x1b\x833\xb8\x80xA\xf9`}\xeeip\xfb3Yi\x18_\xb4\x14\xee\x1e\xab\xf7Te\xc6&\xa0S\x16\xda\xae\xaf\x04\xf4\xe2\tR*\x07\x13E\x8b\x1c\xaa\x9e%\xa2\x0cE\x10\x18\xab\xac\x1eEw\x8c-\x92;\xb4\xa8\r)\x9dFN\xa8\xe2"\x00\x813\x03\xe7_\x16*5\xa2\t\x07qV\x803T\xed\x0e_\x86T\xe9\n'
# b'l\xef\xb4\xa4\xf8x\x1fJU[\r\xb6\xa4\xa5JJ\xa7\x907\xf7r\xf5\x8aq\xc5%N\xa6\xe0\xa6\xf0LG\xac\x19\xb7\xbe\x84\xb7\x87!ZBR\xa0H\xb9H\xd4?\xdd\xb8\xf7\xd6\xff\x00\x1c\xcf(\x87\x03p&9\x96\xc1\x02\xe2\xd7\xb4s5B\x00\x8f?\xf8\xf2\xa2y\xdb\x1a\\;\xcf\x8e\xff\x00:\n'
# b'\xeb\xa3\xfe(6\r\xc6*\'\xc4\xb6\x85\xfd\xf2\x9a!\x83{\x8b\xa6\xf3&\xdf\xcd\x0b\xc16\xa5\x8e\x10TGAV\x9aB\x81\x82 \xf4\xa5l\xa84\xd4\xa3\xaa)\xa8\xfb\xd9\xcc\xd1\x94\x84\x80\xe3\x8d\xbd>\xd5\x8bf\xf6\xda\x14-\xd4\x10i\xe3\x07\xda\xa5\xa4\x80\xea\x12S\xfd\xc8?~\xea\xc6Y\xc5%*Jm3q\xceI\x00O "\r\xfe\xb2\x0fa\x9f\x88\x89\x8b\xdf\x91\x8b\x8d\xad0F\xdc\xa3\xad(\xdd9\x1d\xa6\xb5}]W{n\x1f\xac\xddp\xb8\xa485!@\x8f\x0f\xbbT\xa4V]\x93\xe7\x1a\x00\xd2\xa2\x85\xf5\xb9J\x87\x88\xe4|E\xbc9\xd6\x85\x95\xe6\x01\xc4\x82H\x9f\x03\xfb\x81A\xcf\xcc\x07S\xd2\x1a\xbd\xc3bA\x9e\xe5\r\xba\xda\x8e\x9e \x0e\x93\xb7\xca\xbf-f9;\x8d\xbePH\n'
# b'%Z\x7f\xc5:\x88\x13\xf1\xf7u\xdb~\xed\xb7\xf5\x04a\xde\x18L;}\xee!E(\x93\xec!K0\x01\x8fh\xdeH\x91\xe7X\xbex\xe0V)Ff\xd1;\x98B\x94\x91\x7f\x1d:\x8fR\xa3DU\xccM\xac:\x04\xc1o\xa42%\x17T]F\xe4\x9d\xe29\x0f\x8dr\xfeg\x88u!%\xc2\x00\x00r\xf0\x06|,\x0cu\x9a"\xa6\xc2\xa2\xfb\x95\x0f\x9c|-V\xf0\xf8\x04(\\\xden9\x8f\xdc}\xf5\xab\x1a\xe4\x87\x95r\xac\xc5\xc6\x82H\\\x8d\x887\x1eE\'x\xf1\xdb\x979y\xc1\xe0\x9b\xc5\xb6\x14\xcc%\xd8\xe2h\xec\xa2\x04\xf0N\xc6?I\xf4\xa82\x1e\xc1\xad\xee)\tI\xdeD\xfc\xf6;Q\xa6{\x16p\xee\x05$\x9d\xed\xa5Qa\xf2?\xb5PX\xd5\x1c\xa9\xfd!Eip\xe2\xdf\xdf\xcc\x8b\xb2\xbd\x9e\n'
# b'Wx\xe2l\x0e\xc7\xc3\xef\xe1V\xfbi\x94%)\n'
# b"H\x89X\x9fP\xbe\x9eB\x9a\xf1\xac\x90\xcf\t\xb9\x95N\xc4\xf5\xf5\xaa\xf8\xd6\x03\xdaP\xa3}\xe4\xf8\x02\x07\xcc\xd6\x82\xdb\xcb\r\xe2c\xd8\x9c\x18\xaf\x91\x00v\x1b.L-J\x13\x07\xe8?z\x9f\xb4\xf9PA\xefR,\xbd\xff\x00\xd5\xcf\xdf\xbf\xbe\x8c`\xb0}\xd0RA\x07P1\xe7\xb7\xed]\xba\xce\xa6\x0bn\x1b\x93\xc2fc`\x9b\x9f\x13\xf14;\x0f\xbb#\xb4g\xa7r\x0e\xe6i\x8a@\x9b\xda\xab\xa8(]*\x04m\xf6\r]\xc7\xa7J\xa1C\xef\xce\xaa6\xc2\x16\xae\x15\x14\x9e^~\xb1\xf3\xac\xbb\xc6\x0c\xf4t\x1c\x89\xd3\x8b!$\xb8\xdc\x01y\x8d\xcf\xd7j\x18\xfe'\x0e\xbdE^\xd4X\xf1\x031n\xa3\xe1D\xf1\xaay6I\n"
# b"\x1d\x0e\xfe|\xbet\x03\x17\x8c+2\xb4\x12\x90#i\x8fR?j\x05c'1\x8b\xdb\x8a\xf1\xfd\xa4d\\\x00\xf1\x81\xb7\xe6$|\x14F\x9a\xf1CeC\xbct\xc1\xe7\xac*=\x12\x95\x9fJ\xa0\xf2\xd8&u(x\x04\x02?\xf7\x05J\xde5\x94\x91\x00*7\n"
# b"i\x17\xff\x00\xb9\xc5\xfc\xa9\xccL\xaeX\x8f}\x9e\xff\x00\xe9H}\xb4\xa1\x0f\xbc\xa3\x01%\xc8Ju\xc8\x83\x00\xa6\xdb\xee\x0f*'\x8e\xcf\xf1\xae\x08\xc1\xe5\xdd\xdc\xaeR\xb2\x9b\x15A\xbf\x12P\x83mW\x93U\xbb\x15\x9d\xbc\xb5\x13\x84\xcb\x9al\x14\x84\x97\x02@\x12\x9dW\x90\x94j*&\r\xe0i\xaf\xbd\xae\xc2\xe6n6\x95b1L\xb2\x82\xb8\xd2\xd9P\t\xe1U\xd4F\xe6$i+#\x8a\x86tw-\x91\x81\xf7\xf9\xfd\xa6y\xda\xdc&!/\x83\x8cx-\xd5\x0e \x82\x14R9\x03\x1aR\x9ev\x13\xce\xac\xf6W.\x0e\xa8\x05\x14\xb4\x93<J\x95m\xe3\x00|F\xfb\xd5\x0c\xe3+i\x0e\x04\xb7\x88K\xc0'R\xd6,5\xf1BBA&=\x992w<\xedO}\x86c\x0e\x90\x8e\xf9.\x95\xa8\x80\x828\x12\t\x9d$J\x811\x1a\xa7M\xb4\xf8\xd7Zp\xb0\xfd*\x92\xe4\xe0\xea\x1c\xed\x16^\xa6\xb0\xbf\x86Z\xb5wN4\xa4\xaan\x12\xe2\xbb\xa5\x81\xfe%KJ\x80\xe5\xa8\x0eB\x90r\xf4\xca#\xa1#\xe3L}\xa0\xcd\xcb\xad\xa2\x16\x9dC\x04J\xc7\xfeN \x14\xc0\xe4Ov\x93'\x90\xa5\xfc*JV\xe29\xa5d\x1f=\xbe\x94\x0f1\xfa\x89\xe3\xbf\x9f\xe7\xf9\x04\xce\x8a*7\x1b\x15+\xeb\x8a\xe9\xb4\xc8\xbdH\x96}\xc1\xce\xa6\x86\xe2SG\x1ej\x87<\xdd\x1d\x0cJ\xc1\x02-\x15\x01\xa2\x0e\xa2\xb9k/Z\xee\x84)Bb@&\x89\x9cE\x18M;4\xcc\x87s\xa5\xa5 >\xa1\xc0\x1c:\x12\xa3i\x85\x1b\x12\x01\xd8s#\xd2L+-w\xa5***\x08\x07\x86\xc3WQm\xa4[\xf7\xa5>\xd4\xe1\x1c*mL\x82P\xda=\xab\x13\xaaJ\x89);\x8b'\xebG?\x10{\xe4,l\xb4\x19\xf5\x85&\xfe\x03P\xff\x00w\x95m\x82K\x19\xe5\x8d` \xc7\xd6|\xcc\xb2`\xf0C\x88Zx\xec\xadCH\x04\x8e\xb2f\xf6\x8d\xe9s\x15\x96\xb8\xd4\x85\x02\n"
# b'z\x13\xcb\xc4X\xf3\xa6\x17\x1f\xd2\xd1\x12\x00J\xa6zB\xa7\xef\xca\xa6{\x12\xda\x89\n'
# b'2\x92\x9dS i\xd3\xb9\xbf(\x8fw\x8d\\\x8f\x99L\x904"\xf3\xa9t$B\xd6\x12F\xc1j\x00\x9f\x107\xa8\x06\x15\xe5X)\xb1\xe3&}\xe4\n'
# b'r\xc9\xb0\x8c>\x98\xd6\xa2\x13\xb8\t\tP\x07h\x92G-\xc4\xedW\x15\x93a\xc3jX.]ZZI\xd2J\x8c\xc0\xd8\x0bX\xd5X\xaee\x91\xdag\xe7\xb3\x8e\xa7\x8aT\xa2/)\x05\\\xfa\xcf\xad7d\x98\x07\n'
# b'\x0f\xe2\x0e\x95O4\xa5\n'
# b'\x83\x06`\x1b\xed\xd0\xf8oE_\xcbR\xca\xd2\x90\xe0R\xc8\x9d!&G\xc7\xa0\xae1\x187\n'
# b'a\xb0\'\xa91\x1e\x80^\xa3\x82\xb6\xc4\x86\xea\x1dN\x0c\x81XT\xa6\xe1\xcdG\xa4+\xe6@\x1f:r\xec\xfe%@\x013\x11c\xcb\xc8\xf2\x14\xbc\x8c\x19JS\xac\x82\xa8\xbcO\xce"\x8ddi\xe2\x14\x0b\xfate\xc8\xef\x1c\xe9\x7f\x15\xb4\x1fI\xf6\xbf\xce\xd3-\xcc\x1c\x8c\xe9\xd4\xaa\xf0\xb7\x14\x95y6^\xf3\x06Jn/?\x05\\l\xf7\x89"\xf0\xdbz\x8f\xf9@&=\xff\x00\n'
# b'\xdc\xfbe\xd9\rk\x18\xd6\x02C\xad\x82\xa5\xa4\xdbX\t3\n'
# b'\x1b\x1d2<gqY\x0b\x19[!K\x0e:\xea#e%\xbdh\x00\xfb:\x80:\x8c\x88\x98\xdb\xc6)@5\xa8\xcf/v\xe0\xb61*\xf6z\x19\x1e\x80\x7f>\xfa5\x96b\x01RA\x02<\x05\xfch{\xc1)TY@l\xa10|\xa4\x0by\x8a?\x80\xc2\x1d!IO+\xda\xb8\xea\x10nk\x99>=\x01\xa4\xa5?\xa4\x08\xa8\xf1Y\x81Q\xf6v\xac\xe7\x01\xdap\xc1%I\xd5\x03\x9a\xc2~`\xd7\xc6\xff\x00\xa8\xe1j\xd3\xdc\xa8^\x01A\x0b\x06}\xc6\x81b\xe4j1G\xb5\xb75|"\xbb\xd6\x08\xe8H\xff\x00\xb8\x1f\xadP8m\n'
# b'P\x06Ov\x98\xe5}J\xaa\xbd\x8c\xcf\x02\xdes\x0c\x12\xadI\x01K:N\x94\xf4\x05Q\x1a\xce\xa1\xc3\xd2y\x88\xa3\xf8\x8c7\x11>C\xe2O\xd6\x8b\xd3\xb1\x0b\x83\x15\xebj\xcd\x85\x96\x03\xcd1\xbd\xd6\x85\x19#\x8ay\x9eG\x9f\x8dt\xd0/%.\x05p\x13\xd4\xdc\x03\xb1\x1db\xd0zU\x9c\xc5\xb0R5LLZ:x\xf2\xaax,B\x12\x92\xdaM\xa4\xc7(\x8f\x8c\xd3$eu\x14F\xc3b\x00\xed\x8e\x03\x88\xad>\xc9\xfd\xafJ\xae\xe4\xcb(S\xa8Q\xd4\x80\x15\x1am\xb1>\xd6\xae\x80\xf2\xdf\xdfZ.=\xadhZ5\x02t\x92\x94\xf50c\xcb\xcb\xf9\xabY6\x00\xa5\x80\xd9H\x1c\x04\xac)36H\xfb\xdf\xad!j\xeem\xd1q\t0\xc5\xe6\xcf\t\xe2\x90g\x7f\x1a\xa43E\x03:\x10H\xe7q\xff\x00\xf2E\x14w\x02\x90\x04\xab\x97!T\x97\x83\x07a\xef5L(\xf1\x1dng\xcc\xacsd\x1f\xfa\x8d\x15\x1ed8S?\xfaMp3\xc4\xa5@\xb6\xc0\x11\xfd\xce-_-5e\xcc\x95gf\xfdg\xf7\xae\x06F\xe8#Si\xbf\xb2\t\x82|\x00\xe6j\xe1\x96&\xea\xc2\x13\xc0\x7fR1m\x00\x94\xe8\xd3**\x010U\xa8\x93\xbf/N\x82\x96\xb3L\xef\x10\xfa\x8a\x9dy\xc5\xc9\x9e%\x92\x07\x94\xedE0\xf9;\x0e[\xbe\xee\x95\xff\x00\xecH\xd1\xe8\xe2H\x03\xfd\xc0z\xd1L/\xf4\xe5n\x8dH\xc5\xe1\x8aw$(\xaa\x00\xdc\xc0\x1fZ\xec\xa2\x99C\xcc\x8cD\x96\x9c \xcc\x99\x17\x07\xc4S\x9e?3R1\r\x01\x11\x03{\x83+\x1bz\x1f\xfdT\r\xfc;-\xa1II*&F\xb5\x08*3\xfaP\t\xd0\x9d\xa5D\xc9\xd8\x01\xc5U\xdaZ\x96\xa4I%^7\xd8\xa3\xf6\xaa\xba\x86\xef\tM\x8f_o1\x9b\x06\tF\x1a\xf2\x1c\xc3\xad1\xca;\xcd?2}\xd5hc\x02\xb1/\xd8\x02\xa5(\xdb\xae\xa3\xfb\xfc*\xeff2E\xad\x19k\xa4\x80\x85\x9e\xeb{\x80\xce%\xc7\xdeQ\xe8\x90\xda\x00\x9e\xaa\xa5\xbc.()\xf0\xe0\xf6V\xb3\x1eJ1\xf5\xf8R\xe5w\x98\xfdW\x9cc\xed\x0bbRA\x9a\xe5\xbcQ\xa2\xe7\rk\x8d\xea\x8b\xf8\n'
# b"\x80\xc3\xb1\x8d0>'-\xba\x15\xbdA\x8ab/h\xaf\x83\x0e\xa0b$\xd4\xb8\xa3\xc0g\xd2\xae4u\x17~\xd0\x0e!5\x02q\x0bM\x92\xa5\x01\xe0MY\xc4\x1a\xa6\xb5^\x8d\x88\x9bM[7em\x02\x97\x1b(\xb4\\\x1f\x9e\xd1A]p\xe9\x91\xbc\xc5h\x0c\xf6\x95e:\x1fm/#\x9c\x8b\xfe\xd5O\x13\x94\xe01\x12\x18w\xb8s\xfb\x1c\xb2}\xf5\xaeme\xfc\xe3\x1fQ<\xed}=V\x7f\xa2\xd9\xfa\x1f\xe7\xed\xfa\xcc\xc7\x1c\xa3\xa0\xa6N\xf7\xf7\xd0|S\xc4\xa8\\\xc1\xe5<\x87/\x91\xf4\xa6\xde\xd3\xf6c\x15\x87\xf6\xda%\x1c\x9cO\x12\x0f\xa8\xdb\xd6\x80\xe0\x98T\xc8\x13h \x89\x913\xf4\xa1\xfa\xaa|\xc2\xfa\x0e\xbd\xd4\xc7\x8e\xcf)\xb4a\xd0\x96\xe4\x15\xd9j\xe8\xa5{G\xd1 \x11\xd4E\x198\xa4\tr\xdaQ\xc2\xd2y\x08\xdd^0 \x0f\x19\xa4\xec\xa1\xe57\xc2D#\x88\x81\x1b\x15D\xdf\xa7\xb5\xef\xa3\x0c:\xd1RI iN\xa0&\x04\xf8\xf9\x12U\xe9FR\x08\x89=d1\xcc&qj\xc2\xa1N\x91\xaf\x12\xe0\xe0L]\x00\xec\x0fU\x9f\xbd\xa4\xb0\x0c>\x98\x9b\x98\x13kO3\xeaoY\xd3Y\x8aV\xe3\x8a\xd2^ \xf0%E:TS$\x82\x15\xbc(\t\x1b\xf1N\xc8 \xe8\xf9Ng\x87u\xb6\xd4\xa5\x04)i\x9d:\xb5'r=\xaeB\xd2.,v\xa0\xbb\xe0\xcbz\\\x84\x1a\xa6\x9d\n"
# b'\x12\xa4()d\x9dD\x8d#`\x94\x89\xe27H\xd8^I\xde\x8d\xe5\x8c\xc1\xe9\xf7\xe7E\x93\x80A\x12\x12g\xde+\x843\xa7\x95\t\xaf\xc8\xc4\xb2\xf4\xfc[\x91\x8a\xff\x00\xd5\\S\x83\x03\xa1\xb2@Z\xb4\xb9\x1b\x94\xc1\xb7\x911=}\xf5\x93a\xdeK\xc8X\x01R\x12\x01\x8f\xf0\x04\x02@\xb9I\xde\xdd/\xbdn\x99\xde\x058\x84\x96\x95$F\xc9\xdey_\x97?\x87\xae\r\x9e`\x7f\x0e\xe3\xc9mR\xa6\xd6\x06\xa1\x11%^_\xda>uj\xbf/\xfb\xc2\x96\xf7c\xfbJ8\xb6\xd2\x12\xdc\x00\x14\x91\x04\x03 \x9f\xee\xb5\xafL}\x9b\xed\x06\x92\x02\xc0\xa5U\xe2\x14\xa25\x19\xb4zx\x01\xb0\xab\xb8f\x05\x8dQ\x86\xe3\x8b\xdbq\xf34\xc9\xf0\xef\x00\xf3!\x01`\x83\n'
# b'\x13\x7f#\xcbz\xbd\x91\xe5\r\x85~!\xf0\x95<\\\x0b\xb0\x00X\x04\xc5\xbc\x00\xa5\xcc\x95j\x91\xce\x983L\xbb\x12\x02\\d4\xb2\x12u%\xc0\xa2\x13\xb1\x04\x01\xb9\xf7P\xd8K\xa1\xde\xe6\x97\x90\xe5M\xb4\x95\xa9\x13.(\xa8\xc9\xdaT\xa5@\x1b\x01*W\xbe\xadbY7\xaa\xbd\x95a\xf4\xe1\xd0_u.-@+\x85\x1a\x02dLnI\x89\xde\x8c\x114\x00H2I\xdcX\xc6\xb3#\xd7\xe9B\xb1\x98f\xcd\xf4\x8f\xf2\xe4?\xe6E7\xe2\xb0\x01B\xc6\x0f#K\xd8\xcc\xa5AF\xf1o\xe7jn\xab\x01\xd1\x8a[N\xf2\xb0H\xc6\x86\xd4\xaed\xc7\x11\x06O\x90\xe7\xca\xb9y\xccL-\xe4\xca\x12\x94\xee`\xa8\x89\x13nC\xc0\xd1\x01\x82JHP\x00\xa8s&\xf5\xf7\x12\xb5\xf7\x0e\xc0\x02RA\x1d\x02\xb8O\xd6\x96\xb8e\xa6\x97Jp\xb8\xc4\xc9sV\xd2-\xb0\x14\x05\xd5}\x9f\xe2\x99\xf3\x84\\\xd2\xd3\xac\xdfx\xf7\xfd($\xe2k\xb2\xfcJ\x9f\x8dRl\x14G\x92\xa2\xa1\xfcL\xaaJ\x84\xf5*$\xfc\x05Y^\x17\xfc\xc7\xbc\xff\x00\xf1\xa9\xb0\x99V\xbdg\xbd\x8d)\xd4n\xad\xa4\x0f\xed\xf1\xae\x0c\xa0d\xc5\x8d.\xed\xc4w\x97\xb2\xe4\xe1\x9e2\xf2\x9dB\xaeTR@\n'
# b"\xf1\x85%ZI\xb86\xde\x0f;7\xe7\xbd\x91\xc3\xbb\x97\xadl4\xd3n \x05\xa5\xcb\x95hO\xb5\xadW*:d\xd8N\xa0,\x06\xc8\x19\xd6\x14a\xd6\x02Vu\x88$\x82u\x03\x00\xf3\xd8\x82`\xc71\\/0\xc4\x85\x00\xa7 \x14\x85\\\tX=f\xc4\x18 \x8ew\x1dk\xb6\xd8 \xea\x06\xca\xf8\x12\xad\xdf\xe9%V\tX\xacAZ\x01=\xf3\xcbRRG\x1a\x93:\xac\x91\xb2x\x8f\x14\xc0\x83s\x17\xa8\xd3i\x0e\x98\xd2\x03P\t\x17IPT\xaa\x0f\xea\x02\x00\x9eq<\xe9\x93\xb2\xb9[\xcaK\xb8\xc5\xadA!$%:\x8e\xa7J\xb8e]A\x1c \x1e]-+Xf\xa4\x8d\x03\x80\x9b\x13\xfa\x95\xb9>)L\x15\x1f\xf4\xc5q9\xcc\xe5\\\x10a\xce\xd8g\xc1\x08N\x19\x8e\x146\xd7t\x9b\xff\x00q\xef\x1e\xbf=K\xd2\x93\xff\x00\x95\xe2h6Z\xc1!\xb07%\x00z\xc7\xd6\xbe\xe5\xb9J\xb1\x98\x84\xb6\x89\xb9\x89?\xa5\x03u\x1fK\xf9\x98\xe7m\x17.\xec\x18a\xe0\xa0\xe8[HPR\x02\x87\x1d\xae\x01\x81\x16P\x06~\x147<Db\x95\xcbg\xc7\x88I\x19X'k\x88\xf2\x8a\xad\x8e\xc1\xa6T\x00\xe2D\x05\x0e`\x91\xa8|\x08\xa3\x8f\x00AB\xa6\x14\n"
# b'Lo{\x1a\x8d\xf6\x02\x12\x00\x1c\xb4\xea1\xa9^&\xc2N\xe6y\xdc\xd2\xde#\xe1\x8f!\x14\xd4\xd9\x02\xdb\xf2\xa8qXIL\x9d\xe8\x86!\xd1\xdf\x16\x88\x02\xd2\x83>\xd4{@\xf4#\xee-Uq\xaa\x83\x00\xfd\xf4\xa9Rs,\xe00\xd4T\xcc\xb2\xfd;\\P\x870\xe6i\xd5h\x9b\xabj\xa2\xf3h\x93\xa4[\x94\xefM-\x91\x0b*\x9aR\xd81J\xbd\xaa\xc3\x10\x9dP`D\xc6\xf1\xcb\xe3Z\x01E\xb6\xa0y\xe6\x1a\xc4(JT\x08\xb8\xb1\xf0\xaf@\xaf\xcbS\xc0\xf0\xf4\xd80\x89y?h\xb1xt\xfe[\xca\xd3\xcd\n'
# b'\x85"<A\x91N\x9d\x92\x7f\x0b\x8bpw\xd8f\xdbv\x0ch$!Go\xfa{\x03\x17\xb5g\xf9\x86\x05L\xaa\xd2Pv<\x81\xe8|~\xf9U\xfc\xb9\xe2\x8b\xa0\xc1\xf0\xb1\xfb\x8a\xce\xeaz/P{;\xcd\xfe\x8f\xf1.\x19[\x18\xe0\x8e\xfeG\xf3\xe2j\x1d\xa0\xecrT\x9dL$\x03\x17L\xc0>"y\xd2~#&-\x91\xde&#p@\xf4\xf4\x98\xabY^b\xf1\x1aR\xe2\x84\x8871\x7f\n'
# b'\x17\x95g\xed\xb4\xe3\xad\xe2VB\n'
# b'\x14\xdb\x05\xe4\x90\x98*\xd2\xb5\x03`\xad:[\xb6\xa4\xd8\xd8\xf5^\x91}6c\x1a\xc4j\xf3E\xf4\x12\x1c\x12;h\x83\xfa\xc1\xb8\xa6P\x1cV\x84\x80&\xe4lm\x04\x01\xb7_?+U\x9c\x02\xc9R\x02}\xa3\x11\xe6o\x06lA\xb1:\xa4xQ\x06\xf2T-\xa4\x1e\xfd\xb2\xe1J\x89\xb2\x92\x82$\x94\x90\xa5\x00\x00)(\x8dP\x0c\x93&\xa8\'\x0e\xa6\xde)"\x0bjP1\xb4\x89M\xbe5\xafS+L\x0bC \xcc\xda\xb2\xb7\x82\x9bO\x14\xaa\x06\xaf8\xbf\xc6\xac8\xd05\x8df}\xac^\t\xb4\xacJ\x94\xb2B\x13x\xb4\\\xc6\xe2H\xb0\xde\xfbR\xda\xbbm\x9a\x02\xa7\x1d\x18\x84\x00\x0cp\xb8\x94\x03\xd0\xea\xb4GH\xe5I?M\x86\xd1\x8e\xd3\xd43\xd7\x92\xb3y{\x06\xb4\x92\xa6\xe0\xce\xe0\xef\xcfh\xf15\x84g]\x9fy\xb5\xb8\xda\xd0aK\n'
# b'\x04\xff\x00\x89T|\x15M\x9f\xd2\xfe\xda:\xe3\xe1\x97\x9cR\xd2\xb0\xad:\x8e\xa2\x92\x0fS~}zX^5|V\r\xb7D-!_}jR\xcfA\xb0\xc39\x90\xd5\x1b\x06P\xe0\x8f\x06~\\\xcc2\xb5$\x88\x06\xd5\xd6\x11\xb5\x81d\x93\x1e\x15\xbcf\xfd\x85ir[\xb1\xe8i3\x11\xd8\xd7\xday*2R5\x18\xe5\xb7\xc4\xd3Hi\xb3`\xc0\x1bo\xa8a\xc7\xeb\x14p\x18\xe2=\x91z3\x81\xcb\x1f\xc5-\r)\x0f\x10\xa5\x0b\xa9\xe5\x04u$\xa5$\x03`y\x1f\n'
# b'=\x85\xec\xe2\\W\xe6\xb4\x05\xec\xa4\x9d*\x88\xe7\x1b\x99\xa7\x0c\xa7&i\x88Sed\xc4q\xa8\x18\xf2\x80\x05\x0e\xd5E\x85\xa3\xa8f\xde!\xec$6\x84\xa0\x08J@H\x1d\x00\x107\xab\x89T\xd0wq \x0b\x9a\x8b\r\x98\x1b\x99\xb0\xa4Mg\xbcpX\xa4\xe2\x1e\xa8\x9e`+z\xf8\xc3\xe1@\x1e\xb55\x0b\xb4$^\xccr\xb5\t)\xd2gy\x9f\xa1\xa1\x0e\xe5\xef\x10\xa9 \x082\x91&@\xbe\xe4\xdbo\xb9\xa7r*\xbe#\n'
# b'\x14\x0fR"\xa4\x9c\xc6\x12\xfck\x13\x11\xcep\x86M-b\xb0\xd0kR\xed\x16LD\x98\xf3\xb7\xdc\xfaRFe\x96\xa9&\xe3q#\xc4m\xf4\xa0\xd9\xa37+\xf7(",\x96h\x97gOt\xe2\x9fP\x05\r\xa1r\x93\xb2\xb5\r!\'\xac\xa9I\xf4\x04\xf2\xaf-\x8a\xf6r\x9d\t\x0c\x0f\xd3\xc4\xe7\x8a\xfa\x7f\xb0\x12<\xca\xfa\xd0s\x9dI\xe0\x01\xe4b\xee=\xc2\xb5\xa9d\x99Q&y\xcdM\x95\xb8\x16\xb2\xdb\xa3ZVy\xee\x14y\x83\xd0\xf8s\x8f\x1a\xeb\xf0\xc5D%)*Q\xb0\x00I3\xc8\x01\xce\xac\x16\xd0\xd0\t\xdd\xe0\xa0u\x03\xc2\x93\xd3\xa2\xaf\xcfkz\xd3\x1c\x861\x145\x16%\x8f\xde\x1f\xc2\x87\x12\xe8=\xf2\x94\xc9HJ\x04p\xa5@\x83\xc5\x1c\xed\xed\x11\xce<\xc5\xbd\x84\xef\x14\xe2YL%\x000\xd0\x98\x00n\xe2\x8fC\x16\xf5\xa9\xb2\xb7T\xdb|C\xf5\x1e\x1d\x88\x06\x02@\x9d\xc0$\xd8\xf2\xe6)\x97\x07\x80\x08l\x0b\x12J\x97n\xabV\xafS\x11\xee\xa1\x16\xc1\x87\xae\x90\xd8\x9d\xf6_,N\x19\xb2\x11u+\xdb_3\x1f!\xe1G\x8e,\x92\x80\x0f2H\xea\x90\x92/\xfe\xe8\xf0\xa1l\xbe\x86\xc2\x8a\xcc\x01\xd7\x9f;u>\x02\xaae\xcd8\xe3\xcby\x7f\x96\xad)Im \xdd2J\x02\x89\xd8\xf5\x00\xed\x13\x12@\t9\xd9\x8c5`\x00\x04)\x8d\xc4@$r\xde\x96\xb3\x17\\y\xd4:\x95\x8dH \xa1\n'
# b'\xd4\x13<\xee\x927\xd8\xc8\xe6oE\xf1\x8f\x84\x0b\xc1<\x85\x03,(\x02\xe2\x88\x04\x9b\x03\xf4\x145\xd1\xcc#(#\x04B\xeb\x08Z`$"\tP\x00\r\xd4J\x94d~\xa2To\xe3B\xd2\xbb\xde\xe6k\x83\x8a\xd3\x17\xaay\xa6!;\xa3To{^\x04\xed\xcag\xde(\x80\x12e\t\n'
# b"0%\xd7\xd32g\xf6\xa1\x0bA\x9d\xea6\xf3R*%\xe6C\xa7\xc6\x8a\x15\x84Z\xc6\x06o\xabc\x95\x05\xce0\xb2(\xcf}k\x02|9\xfcw\xa1\xb8\xdcJV\x99I\x04u\x1dE\x8f\xaf(\xad\xca\x89\xcc\xf0\x97\x85\xe3\x15\xf1X\x14\xa8\x14\xa8JO/\x8f\xc2\x81/\x08[\x80/3\x069M\xbdi\xb5\xce\x9c\xaa\xa6!\xb4(A\x02\xff\x00s\xe7O,\xcc\xe6D\x1d\x82\x7fN\xc4\xf5\xf5\xa5\x8e\xde- \xb4\x90\xa9'Y\x08\xb7\x0e\xa3\xbc\x817V\xa3~\x86\xfd\x0f8\n"
# b'\x0e\x95\x0b\xf2=h\x1fi\xb2\xe7\x1e)[p\xad)\x8d6\x06\xca&\xd3\xbf\xb5\xb6\xf6>\x15K\x93Y\x11\xbe\x92\xcc6\t\xd4\x8b\xb2y\xde!\xa5\x84w\xc7H\x11\xb6\xa2\x94\x88\'A\xdc\x0b\x0e\x10`\xc0\xa7f\x10\xd9R\x82T\x92w\x8d\x8e\x92lt\x9b\x81\xe9Y3\xcc\xb8\xda\x89Z\x14\x8d\xec\xa0GPE\xf7\x13jd\xecvy\xddj\x0e\x95)\xb5@\x17\x95"&\xe9\x9d\xf7\xdb\x9cz\xd0\x15\x82\x1c\xc6\xef\xa4\xd8\xba1\xc1-4\x87\xdb\xc4\xad+_r\x93\x08@\x04\xc82\x15\xc4@\xe1\x05g\xdcyQ.\xd2g\x98\xacOx\xc6\x1f\x07\xde +\xbaS\x85\xc93\x1cP\x80!!3r\xa2:\x00k\xe6\x0f\x0e\xa0\xb48\x88R\r\xc2\xc1\xe0RT \xc1\xeb\x13m\xfc)m\x9c\xc5\xcc*qk+Z\x92\xec\x93\xad!:W&\xdc\x16R\xaf\x06\x0e\xc3m\xa9~\xa8\x0e@\x8f0\xff\x00\x87\x165\x95o\x10&\x1b&w\x0c\xb0\xb0\xa04\x10\xabo\x05*V\xe3\x90\tW[\x84\xf5\xbe\xc5\x95\xe7KHM\xe5$$\xdf\xa1\x00\xfc\x8ddG0\x18\x9e\xe5\x86\xdb%@\x1dK\x9d%I\xd2\x98L\xff\x00j`\xf1\x1bDr\xad\'.i)a\xb4\x05\x85\xba\x98\xd5\xa6t\xe9"\xc0\x13uD\x0b\xef}\x80\x80\t\x80\xc3\x06\x06\xe6e9\x07\x0689\xda\x16\x10\x90\xa7V\x10\x0f_\r\xeb\x9c\xbb\xb4\xb8<B\xb44\xf2\x16N\xc3i\xf2\x9fk\xd2\xb0\xde\xd0eo\xe2q\x05J{\xda\t)\x01$\x84%|HM\x88\xe2\x08)\x93\x1c\xe3\x95\x0c\xce\xb27p.\x0f\xceJ\xc7\t\x94\x82\x93qc\x07\xdd\xbd*j\xaf8\x06>\xa6\xc2\xb93\xf4\x83\xf9j\x15\xb0\x83C\xb1\x18G\x11qqB\xfb%\xda\x82\xac+%\xf3\xc6Ss\x110H\x07\xdc\x055a\xb1\xad\xb9\xec\xa8\x1f\x0euS\xcd;\xf6\x94\xfe\x95\x9a\x07\x06(b\xf1*\x9f\x9f\xdf1\xe0j\x11\x88\xd2\x99N\xdd:u\x1e\x94\xe3\x8c\xcb\x1bsq\x07\xa8\xa0\x98\xde\xcf\xa8j\xd1p`\xc7\x88\xfe>B\x98\xae\xe4=\xf5\x15\xb6\x8b@\xf9\xf8\x95p\xb8\xe5i\x10h\xfe\x031\xd48\x85*w\n'
# b'M\x88"\xae`\x1dU\xe6\xa6\xdaU\xb6$\xf4\xfdc\x0fk\x88\xe2\x95M}\xa1\xb9~"\x125\x1eCz \x95\x83H\xb2\x90f\x90 \x8c\x89\xcb\xad\x05\x02\x08\x17\xa4\xfc\xcf\xb3\xb0\x1c\xe1II\x07I\x9d\x89\x881\xf7\xeb\x02\x1d+\xe1\x146\\\xc6)\xbd\xea>\xd9\x905\x92\xe9sT\x02\x125\x8b\xd9DN\x94\xf4\xd4T\x00\x8e`\x9aTw,qd\xe9I7\xb9\xe5\xd4\x92\xa3a\xe2I\xe7[\xa6s\x93\xa5\xc4\xcaA\x057\x00\x18\x93\xca\xfc\x8f\xf3\xd6\xb3|\xfb\x08\xe6\xa5\'HD\\\xa5#Jd\xf3\xff\x00U\xf9\xcf8\xb5\xa9VR\x93w\xa5\xea\x17\xa8\xd1\xd1\x88\xd8\xc2\x1aIKfVD-\xc1a\x1c\xd2\x8ezw\x05_\xabh\x03\xda\xa9\x97\xe1\xb5*\x89cpdt\xfb\xf1\xdb\xe3V\xb2l<\x11j\xe0\xd8\x11\x93A-\x83,\xe3\xf0\xe8J\x02\x94.\x8d1\x1e\x1dz\xf3\xaa\x19f=\xc0H$\xc6\xf7\xfat\xab\x19\xfb\xaa\xef\x02\x00\xf6D\xfa\x9f\xe2\xb8m\x93\x02\xa4\rJ\xec6\xa3\x1e\x0b\x12\x95\x91\xaa5\x0b\xa6w\x9e^\x15\x7f\xbc\xd1"n\xab\xc7K\x01\xf4\xa5f\x9a\x12/q\xce\x8c~\x18\xe9*\x81 N\xf7\xf8P\xda\x10(;2\x86d"z\xd2\xd6=\xe5\x1d\x89\xb7\xdf:b\xc4b\n'
# b'\x8d\xed\x1b\x7f\xc5QS\x8d\xa8\x14\xba\x80oh\xdf\xdfP\x87\x06u\xaaH\x81\xf0x\xc0\t\xd6f\xad8\xd2T\x93\n'
# b'\x10v\xb6\xd7\x9a\x18\xfbr\xa2`D\x98\x11`9Q\x0c\x03\x04\x10\x080v\xe9Flw\x11Q\x93\xa3\x06\xe2\xb0e<\xe6\xa9\x14\x9atc\x04\x94\x02\xf3\xa0\x10\x92t\xa4\xfe\xa5o\x1f\xe9\x16\'\xcc\r\xcd-bRV\xa2\xb1\x17$\xfb\xfc9yU\xeb\xb3\x94\x15\xd4\xf1\x193t[\xb6\x9f\xbf\xf9\xa0y\x8b\x9cZ\x93i\xf6\xba\x1eS\x1dG\xa7\xc0Th}Q\xbd\xea\x17\x96I\xbd\xc7:\xf4\x8b^\'\xce^\xeeBq\xdf+T\x14\xc0\xe4f~\xcdy(\xd4<\x8d\xeb\xa6\x99\x92zT\xfd\xd0\x00\xd13\x16"r\xeeX\x8e\xe4\xb8\xe6\xa3\xfd\xa8Dj0@&M\x92\x01;\xc7\xa5.\xb9\x85\x1aJ\xdb\x0e\r1\xde6\xe0\x1a\x93\xa8\xc0PR@\x0bL\xc0\x9b\x11\xa8u\xab\xdd\xa9\xc4F\x11\xa2\xe8\n'
# b"i\x0e.\xc4)R@I\x82\x01\x1c\x8d\x8c\xf36\xb5\x06\xc9\xbbJ\x0b\xe8\x0bD\xb2\xa1\xdd\xb8\x05\xa1\x04@\x03h:c\x9d\xb4\xd2'\xa8qi\x13a:Z\xcd\x01\x87\x91\n"
# b'\xe1Zei(u\x01V\xb1\xe6\x93\xc8\x83\xbf\xc6\x83g\x18\r$\x00\x94\xf7\x86\x02\x14.\x17\x1b\t\xfe\xe3\xc8\x1b\x9b\r\xe2X\xdc\xcaJ\x00q\xb5\x87\x1a&5\r\xd30@X>\xc9 \x8f\x03k\xd78\xac\xbd. \xa1{\x1d\x88\xdcx\x8eSM\xb2-\x83""\xb7\xb5\r\xc5\xbbD\xcc\x87\xb5\xcfa\tAHq\x95{m+o\x1d=\x0f\xc3\xe7E\xb1\x19n\x170\xd4\xeb8\xa7P\x12\x92\xb5\xb2\xbe=\x03u)2B\x95\xa7r\x92I<\x8f\xe9\xa8{U\x92"\xcb\n'
# b'\x85\xaaA\xd4}\xb8\x03\x88\x9eK3~D\xce\xc7u|\x1bN\xb6\xe7\x06\xa4\xaa\xe3\xa1\x82 \xfc&\x94j\xbd\xd8\x9a\xb5\xdc\x199\t\xa5\xe5]\x97F\tDw\x85\xc5\xb9\xa3\x88\x80\x10\xa0B\xf4\xc0\x13\x03\x85V$\xcc\xcc\xc8\x10y\xa4q\rI\xb2\x88\x85no\xd1B\n'
# b'h*1\x9a\x9bb\x0c\xe8BR9\xdd\x02\x07\xc4\x9a"\xd6*"f`\x11\x1e\x1fJ`!\x0b2m\xb7\x95\x99\x8b\xd8,\xbd\xa7q\x18\x85\'\x12\x1b+\xd5\xa9\x01i\xd4\x1cZ\x86\x95i;))\xd5a\xfe=&\xa4\xc6\xe5\xae \xad\x87]C\xa1l\xaau\x12\xa7\x01B\x14\xa4-K\x80,G\xf6\xedk\xda\x85\x1c\xe1xgq\x05\x05*=\xe1P!-)\x17:\x92@\x90\xa1\xca\xfcPG*\xfb\xd9L\xc0\xbe\xea\xdeX1)\x05Gm!AJ\x00s\x904\xf4\x85*\xb3B1y\xe8Y\xd5j\xc9\xf8\x87\xb0\xa8)e\xb4\xdaBo\x1bu\xa9\xf0\xb8\x97\x01\x00\x12\x08\xf1\xe5S\x1c"\x82\x94:\x12=\xc6\x82v\x97\x12\xebA\xb5 \x94\x81\xafQ\x1b\x13\xa7\x81$\xf8\x99\xb78\xadp@Y\xe6p\xcfi\xc6\xb2Lw\xc0v\xb1m\x9d.\xdc\x0e\x7f\xcd7`34:\x90\xa0bk\x19\xec\xdfi\x19\xfc3\xc3\x17\x89mN\xa0+\xbbi\xf4\'\x88\x116\\\x05{\x8d\xb9N\xc1\xf7*\x88kA\xb2\xc0X\xf0\x90\x14G\xa1\x91\xe9Y\xf7W[g\x03\x06mQ\xebW\x80\xc7"8\xb8\xc2U\xb8\x07\xc6\xa9=\x95\x8f\xd3j\xa4\xce-h1\xb8\xaa\xb9\xb7n\xf0\xac\x08*\xef\x16\x0c\x146B\x88#po\xc3\xe5\xbf\x85+\xc5\xd7\xb4d2Y\xdcNq\xed\xb8\x83\xce\xa1\xc2\xe6\xe5\xb9*$\xcc\x10\x07\xd6v\x1e\xfa\xb2\xcen\xe1\xd2\xee(\xb3\x85d\x82CKP.\xaa\xd6\xd51\xa6$\x18L\x9eF(6+4\xc3\xe2VQ\x83i\xd7\xd67\xd24 ^$\xaddi\xe7\xbe\xf0b`\xd1\r\x81\x97\x0c%\xfaz\xfd;3\x9c\x83\x1b\xb2\xcc\xe1\x0e\xd8X\xf4\xa2u\x9f+\x01\x88b\x16\x11\xa5\\\xc0:\x80\xf5\x81>\xef\xdc\x95\xc9\xfbU$\xa5\xd1\xa4\x81\xf5\x8f/\x95.W\xe2iY\xd2\xf2\x1c\xea\xd8\x8d\x95K\x1f\x966\xe8\xe3M\xe2$X\xff\x00>F\xac\xb2\xf0P\x94\x99\x06\xa4\xaa\x10\x0e\x8cP\x16S\x91\xa33\xcc\xef\xb0\xaa\xba\x9a!\\\xf4\xc4\x13\xf4\x9f(\xe7n\xaa_\x83SD\x85&\x08\xdey\x1f\xa1\xad\xc2\x97\xb3\xde\xcc\xa5\xf5kI\xd2\xae}\x08\xfaR\xf6S\xe5f\xcfG\xf8\xb3\x03\xc6\xe3\xaf\x99\x92:\xd9[\x85do\xf2\x02\x07\xc2\x881\x85\xb6\xd4w\x19\xd9\xb5\xa1F\xde\xf8\x03\xe7\x1f\x1a\xe1\xbc\n'
# b"\x85\x88>#o\x9d\x08dw\x9a\xbe\xb5L2\xa6\x0f^^[:\xd6\x98\x06\xe9\x91b\rq\x86{Q\x88\xa7\x0c;A\xd6\xfb\x97-\xfd\x8a\xfe\xd3\xd3\xc8\xd0're4\xb3)\xb8\xa2\xd9^\xb2 *\xbc\x12U\xb4eLfP\xde\x90\xa4\xab\x88\x83)\xe9\xd3\xce\x97q\x18\x0b\x90A\x9a1\x86\xceP\xacS\x98`\x14V\xda5\x13b\x928DH3 \xa8r\xe4h\x9e`\xa5\x06\xd5\xa5\xb4\x974\xc8\x07\x99\xe4(,\xa4\x1d\xeaY.\x04g9\x11-9P\x16\x82O\xca\x89`\xf2\x9fd(\x84\xde\xf2n\x04L\x84\x9d\xc9\xe4\x07>\x94\xaf\x9ev\x93\x15\xa86Y-\x14\x80]@J\xd2\xa30o\xfa\x90\x82\n"
# b'y\x83}\xe8\xefe\xfbh\xc7\xb2\xe3M\xb6O\xebm<@x\xc9*W)\xbc\xdb\x9c\x01Wz\\\x0c\x98:\xfa\xaa\xd9\x88^\xf2\xded\xd2\x9c"\xc4!"\x12\x9e\x83\xead\xc9<\xc94\xbc\xbc\xb1Sm\xabM\xc74\xd2\x90\x14\xda\xdb"&B\x81\x99\x8d\xbe\xf9\xd2\xcb\xc5\xa0H%3\xcf\x88P\xd5\x8a\xcer,\xdc"\xd6"\xd2k\xa7H\x10j\x98v7\x8f\x03Ra\xde\x07\xa1\xfd\xeb\xd9\x91>S\xd8\xcf5\x9a\x86^R\x1c\xd6Q\xa3_x\x13 \x00/)H\xbd\xf7"#P\x90\x00\x9a\'\x98\xb6\xb7\x99\x0b\xc2)\x12\xa3e\xaa\xe2 \xede\rS\xa4\xc1\xe4\x08\xb1\xd8~X\x82\x14Xt\x87\th\xb8\x95\x14\xc4\xa9+\xd2`\x03\xc2\xa0\x14\x88 \xcf\x95*\xb3\x98\xe2p\x8e,/T\x13\n'
# b'N\x90R\xa9\x02e&\xc4\xc1\x1e\xeet\x8b3\x035\x12\xb4q\x1d\xb3T\xc6\x19i0\xa0I\xb1\xf6G#{\xc6\xca\x04\x8b\x8b\xd6\\\xac8B@:\xcc\x93k\x08\xd5\xc5\xb0\xeaF\xdd\x12/j.\xf6)0\xa4\xb0\xa7t\xba%M\xa8\xc8\x93$\xdb\xf4\xcd\xa4\x89>5{\x0b\x91-\xdb\x99\xd2\x90\x08\x1f\x01=N\xff\x00\xc5J\'&\xe5\x08\\R\x9cI\x96;1\x99\x9c8J\x96\xa5\x14N\x8d1\xa8\xaa\x7fHLI<\xe2\x8f`s&\xb1\x0bZ\x1b\xd6\x95\xa0Im\xc4\x14\xb8\x01\x8d\xc1\xf3\x1bu\xe5Jy\xa6\x15\xe6\x92\xd3\xc8I=\xd2\xce\xa0\x91}\x0b\xd3\xd7\x91(\x8d\xa2\xe3\xad\x17\xc9\x19?\x8cV1AM\xb6\xebD\rq\xa9F\x13xH\x00\x03\x00\r \xcc\x11\xbc\xd4=\x85,\xc4\xa9\xe9\xd2\xday\xe7r~\xd8\xb2\x08I\xe6\x94\xc1\xb5\x8c\xef\xeb\xca\x97p\xd9f!cZY*m\x16R\xc2I\x027\xe2\x1e\x11jy\xc7`\x89\x17U\x948c\xaf\x9fO\xde\x80\xb7\x88(al\xa9@(kCd\x04\x82\x03\x8d\xa8\xd8\xee\xa5\x95\xa5B\x04\xc0RdF\xe5\xb6\xce\x08\x19w\x01\xd2\x8elQ\xb5*\xe1\xdc)\x81\'\xc0\x0f\x1f\x0e\xb5O\xb4y\x8a\xd2N\x1d1\xa8\xdd\xc3;s\t\xb7\xbe\xdc\xc8\x1c\xab\xd8\xdcwvT\xb4\x90\x08\x98\x1f\x0e~qA\xb1z\x96\xb0I\x01j \x02\x9d\xc4\x89&\xfbD\x98;\xcc\x1d\xc5\x12\xc6\xce\x84\xea+\x01\xb9\x19\xf7\x0b\x97%\xd5+W\xfd4\x10$\xc5\xd4\x04,\xf4\xde\xdb\xfe\x9ag\xcb1\r\xf7gH\xb0\xe87\x88<\xef\x1fq\xb5\x07q\xa4\xa1\x1a\x17\xa9(l\x00\x94\r\x89\x1b\x95s\x11\xd3ss\xd0\x1ax|qH"\'U\xc2F\xfe\x1e\xfa\x80\x14B?+6\x0c\xd6p\xd9\x8a_gP\xf6\xd0\x02\\\xf1\x00@P\xfa\xff\x00\x14?\x11\x89a:\x92\xea\x91\x04q \x90I\x1b\xfb;\xf4\xa5\x8e\xcag\x8bh\xc3\x89\x80F\x99\x99\xb6\xc2@\xb8\x11\xce\xa6\xedSIZ\xd0\xb6\xc0:\x80\x05@\x13=&7\xb1\xf8UQ;\x81\xda\n'
# b"\xc1\xee\x04\xc5L\xcf.\x0e\x15% \x99'\xba\xd2B\x95\x13`t\x98\xf6w\x13\xc8\xf9\xd6\x9b\x89\xed&\x1b\x02\x1a\x13\xdf\x14\xa3B\x03d\\\x80\x12T\xa2\t\t\x9d\xe2\xfb\xd6_\x8b\xc69%\n"
# b"Y\x16\xe2\x17#\xca6<\xe8\xaeG\xd9\xe7\xb1\x0e\x1e\xed\xc6\xd4\xb4\xc1!\xc9\t\xd2@\xb8!*\x99\xb5\xa3\xe4j\xafX\xeec\xca\xfa\x19\x84\xf3\xbe\xde\xe3\x1c\tJ\x10\x18\x0e{'I2&\x0f\x11\x1bx\x88\xd8\xd4Y.d\x94~V\t\x9e\xf3\x11\x04\xf7\xeaJ\xb8:iJ\x8a\x83i\x81bM\xc9\x13\x1c\x8f\xe2\xfb.\xce\x1d\x95\xbf\x8bqN\x04\t\xd0\x8e\x14\x99 % \xfbD\x92@\xdd;\xf4\xa8\xf2\xdc\xe1\xe6\x10\x0b\x98\x14a\xf0\xa6\xe1m\x94\x14\x80m*\xd2\xa2g\xa9 x\xc4R\xc7\x8fa\t\xc8\xe0\xe0Ir\x9c\x99n\x91\x88\xc6\x95\xa9\xc3#\xbbQ\xb6\x90xd\x08\xd2w\xe1\x98\x83q$\xd3\xbe[\x9c6\xd2B\x03iBF\xc1 ${\x85\x07\xd5Qc\x19$\x18\xab=+\x8d\xcaS{3G\xac.=\xb7G\n"
# b'\x81\xf0\xaa\x98\xec\x81\x97$\xe9\x82A\x12<|+7}\xc7\x10d(\x82:Q,\xab\xb6\xee6t\xb9\xc4>\xf9\xd2oW\x1e\xc6n\xd5M\x84r\xac\xc3\x8c\xe5\x98\x8c$\xe8\x97\x1b\x99\x81\xb8\xf4\xa29wiP\xa5\x049(WR \x1f^^\xb5.Y\xdaV\x1d\x1b\xe9=\x0f\xefW\x9f\xc0\xb4\xe5\xcaA\x9ec\x9f\xefC\'\xe6M\x8f\x93\xfde\xdf\xcfil\x1a\xfbUp\xec\x14X\x19O!\xd2\xac\x05Ub\x84|O\x8e\xb4\x14 \x89\xa0\xf8\xbc\x9c\t\xd30~\x1f\xc5\x1b\xafU\x19A\x97K\x19;\x18\xba\x9c\xb8\x03\xf5\xaa\x1d\xad\xc2Kju\xc5\xb6Ym\xb3\xad\xb75\x04\x926\x9d\x07\x8aE\xb4\xa8(LZ\x9a\x9dfA\x8a\xcf\xbf\xa9l\xb2\xbe\xe7\x0c\xeb\xa9i.\x12\xb7]YH\xee\xd9n5i*\xb0Z\xd4R\x91\x172w\x02*Q\x8a\x18Vo[D\xc4\xef\xe8\xfap\xeay\xf5\x17\x82\\P\x08C$\x80T\x91\xc4U\x1f\xa8\x8b\x01\x1bqu\xa7\xbc\xf33\xc2a\x9cm8\x87R\xdfxN\x9d@\xc5\xa2I B@\x91sH\xd9\xf67$[\x0e5\x84\xc3C\xa1#\xb9}\r\x14\x0e\xf0Y?\x9a\xa2\x14}\x9b\x93cssI\xbd\xba\xed1\xc6\xba\x16\xaf\xff\x00\x1c\x86\x92.\x02f\xe1j\x99+1x\xf0\xda\xba\xd3\xea\xbf#\tQ5 \xc4\xd5\x96\xde_\xde\xe3\xd1\x8cu\x94\xb6\xf2\x99h%N\x04\xea\r4\x97\x02\xa4\x1b~c\xa6\x0f\xf8V-\xda\\\x0bXlS\xcc\xb6\xe7z\x84*\x1brD\x14\x90\x152\x9b\x12&\x0cX\x90hb\xf1\xcb-\x86\xcc\x14\xa7a\xa527\xd8\xc4\xf3<\xea\xa8\xa9PD\x136\xf2$\xca\xc6,\xd8\xa8\x90w\x1bO\xdf\x8c\xd3\xb6\x03\xb6l\xb4\xdaP\xde\x19IJ@\x00\x07\x07K\x92t\t$\xeey\xd2F\x19\x82\xb5%\x12\x01*\x00\x13\xb0\x93\x17=+Q\xc3\x7fF\x1c\xd3\xf9\xb8\xa4\x85\xf3\x08F\xa4\x8fU\x10O\xba\xab`S\xf9\xa1i\xb2\xc59_\xe7\xf7\x9f1*Q \x15y\x01\xd2\xac\xe1\xd2\xa4\xdelv\xa1y{\xba\xeeO\x97\xd7\xe1FW\x8b\x02\x12\x00\xdbj\xf5\x02x\xb6\x1e!\x0c"\x89[k\xd8\xa0\x91>\n'
# b'\x10~\x9e\xea)\x89\xc9S\x88)$\x02\xa1\xbc\xf4?;PF\x15`\x01\xbf\xc8\xd3FF\xf1"H\x82,GO\xe0\xef\xeb@\xb8`dJ\xd3\x9e||J,\xe4h\xc36\xb5\xa9:\xd2\x9b\xaa\x05\xf4\xdbZ\x80\x00\x92Bd\xc0\xde#\x9dy\xbe\xd02\xb5\xb7\x87\xc2\xb8\x95\xebu(p\x91\x01(\x00\x95\x14\xeb\x03QTi\x04Z\xfc\xedG\xbbA\xff\x00\xd9b\x15\xcf\xbaX\xf4 \x83\xf0\x9a\xcc\xf0\xf8\x92Z-\xe8i:T\xa2\xdd\x90\x14\x04\x15\x0ez\x81\xdc\xeb\xf0\x07\x95*\xbc\xac\x13G\x8a!\xcf\x98\xf1\xda\\\xa0!\tqI.$\xb8\x8dIM\xe4L\x8bs\x82\x01\x8eq@q}\xa1\xfc\xc0\x95\x80\x80\x99\x84\x1fl\xcaT&\x07\xb28\xd5\xedG?\n'
# b'\xb4\x9c\xdd\x0f3\xddb\x06\xa2\x90\x08$\x91q28b!C\xe5Kn6\xdaVa1\xe7\xce\xf3\xef\xa2\xa5,\xc7\xdf\x05\xea\xa2\x8c \xc4l\xc3c\xc2\x18V\xb8\xd2\x84\xc8<\xaff\xd3\xea\xb2\x94\x81\xd6:\xd4}\xa6\xc5\xe0\x9c\x04\x86C\x8a\n'
# b'\x00\x04\xabM\xf8H$\xb6l8I#\x9d\xee(\x01\xc56[\xd2\xe4\x98V\xb6\xe2\xe9\xd4\x94\x90u\t\x1a\xacdX\x99\x06\x06\xe6\x97\x1b\xc7.u\x10\x006\x89:f7\x02/y7\x9ew\xa0^\x87\x94?L=\xb9\xff\x00?\xb4jq\xc71\x98g;\xc8\x1a\x7f1\x94\xe9@*D\xa8\x15\x85\x01\xa8L\x04\x84\xa4\xc7\x0f9\x10\xb6pe*\xd5\xd2\x08\x14g\x11\x8cuE\xb5w\xcb\x94\x84\x90\x10`\x03\x11\x00^\xc3\xa0\xa90x\x02\xe2\xc0$!$-JQ\x12\x00Bu\xa8\x00,LE\xa7\xf5\n'
# b'=h\x11}\xdfx\'b\xed\xed\xfbJ\x8eva\xee\xed.b\xb1\x08a+\xff\x00\xa6\x95\xea*U\xc6\xab$\x1d1"\xea\xea=\x02f\x19K\xb8gKn\x02\x95&z\x1f\x97\xdd\xc7"\r\x1b\x19K\xaf\xbe\xcb%\xcdE*^\xb58V\xa4\xca\x8c\xa8\x8d\xa4\x92</\xca\x8bg\x9d\x9d\x0c\x85\xba\xbcN\xb5j\r\xa5+\n'
# b'QR\x825(\x95\x95\x181k\x8f\xd2/p(b\xcd\xec\xc6\n'
# b'`j,\xe5\xaf\x04E\x94T\xa8\xd47\xb6\xff\x00Zi\xcap\xaaq\x82\x89#\xff\x00\x0cxr\x1e\x02/\x1f\xe5I\xf8X\xd6\x15\xb0\n'
# b'0o\x06\xd7\x8b_\xca\x9e\xbb4\xe1>$\x9b\x9f\xdb\xef\x950\xad\xa8\x95\xeb\xda)fX\x14\xca\x86\x85\xa9\xc0@"E\xbc\x86\x994\xfd\xfd,\xca\xb4\xa5jZN\xa2\x90\x02\xbf\xc4\x19\x88\x8d\xe4\xf5\xa8\xb3\x9c&\xb7\xd3\xa4\t\x02O\xbb\xe7]gY\xe3\xb8\\2\x0b$!kp%D\x80m\xa5D\xf9\x13\xa7\xce\xc6\xabq.\x98\x1d\xcc\xb5/\xc5\xf7\xd8fZ\xfe\xa7\xe6\x0c\xb6\xc8a\xc0\xa3\xdeA0-\x1c\xc7\x89"b6\x80O)\x11\x83\xc2~%\x90\xd1\xefR{\x94\xf0\x15\xeal\rV2S$\x8d@o0\xde\xc0\xce\xa4\xac\xcb1/\x93\xaeTM\xb5O1\xb6\xfe5&G\x8br\x10P\xe1\x0f0\xb2@Z\xa5*I\x10"v\xbe\xa4\xc4\xc4,\\M\x92z\xf8\xe3y\x9a5\xb9*u\x89\xb25\x86HO$\xa5"I&\xc0\x01\xcc\x9f\x0e\xb5\x1b\x01.\'[j\x91\x1c\xc1\x06\x08\xb1\x85\x00`\xf5\xaa\x0b\xcd\x99\x7f\x08\x01:\x7f\x10\x95\'N\xa0\x08\xd3\xed\xc9 \x88\x16\x06A\xf6\xa3\x9dZ\xec\xb8\xd6\x87]\xd7\xa8\xb8\xb1\xca\x00JR\n'
# b'}x\x89$X\x93\xb0\xaa\xb3\xb4\x8a\xd1q\xf5\x83s\x0c\x08J\x0c\t=iYxbM\xc1\xf7V\x90\xf3\x01S\xf0\xf0\xa0\x98\xac\x0f\x111j\r\xa73k\xa2\xb7\x88\xc4ViE&6\x8ac\xc9\xf3\x97\x11\xfa\x8f\xadW{\x03\x13"Et\x8c\n'
# b'\xac@\xf2\xa5=R&\xa9dq\x86\x8f\x99vi\xac\t\x14D\x10k:=\xa2F\x1c\x00\xb2\n'
# b'\xad\r\xa6\xeb2c\xd9\xe4\x002I\x8d\x8dE\x9d\x7fQ\x16\x89C\r\xa4\x1b\xf1\xb9\xc8\x8f\xf1\x90\x00\xf1*\xf4\xa9\xf5W\x13.\xee\x97\xdd\xed\x9aJ\x88\x17&\x079\xa5\\\xef\xfa\x85\x82\xc3\xd8,\xbc\xbb\xc2Y\x85\\n5N\x99\x1d&|+!\xce{T\xf3\xd1\xde\xbe\xa7L\x98JT4\xcf\x8e\x94\x84\xa7\xfe\xc9\xb5\x95\xce\x80\xe3\xd4\xa4)A\xcd)XN\xad\t\x06\x06\xc4\x15\x99\x95/M\xfd$\x9eU\x1c\x98\xf6\x12\x05\n'
# b'?1\xcc}\xed\x07\xf5G\x16\xb4\x92\xd6\x8c:H\xb4~b\xcfN%p\x8f $VW\x9a\xe6\xce\xbc\xadn,\xadG\xf5\xb8\xa5-^\xf3a\xbe\xc2+\xe6#\x16\xa5%*\xb9\x83\xc5\xe9\xf4\x83TB%E O!\x1f=\xb6\xab*\x9f2\xcc\xc0\x0c(\xc4\x8d\xc5\xa8\xd9D\x9f\x03\\*\xa6} D\x9d\xadk\x9f~\xd5\x08WA\xebE\x80=\xe7\xd6\x99&mh\xbf\x87/[\xd4\xa9\xfc\xa5\x82\x15>#\x97*\x83c\xe1\xb1\xabA)#bI\xe9{\x9e\x9e\xb5\x06J\xfd;\xc9\xff\x00\x06\xa58\x02m\xac\x830H@R\xc2eP\tJe@N\xf7\x1c\xccW\xe8\xdc>5z\x10\x14\xa4\x15%\t\x0b"`\xa8$j"`\x913\xca\xb2\x0cGf\x95\x85\xc3)\xd7aN~H L w\xcd\x92?\xc8\xc8\x03\xa5\xadZ0nojN\xe7\xf8\x9a}?N2y}?\xcf\xfeL\xdb\'\xb0\x92m\x14A\xd7/&6\xb5\xea\x0c\x13P\x91\xd3\x9d\xadT\xb3>\x12H\xafV\x1b\x0b</\x1c\xb4h\xc9\x82I$\xa8\xcf\xd2\x9drv\x02\xc6\xa0H\xeak\x1b\xc1bVo}\xf9V\x9b\xd9\\d7\xa4o\x17\xfb\xebTrYu\x04T%\x80\xb4p\xcd[O\xe1\x96\x14lRR\xa8\xe8\xae\x19\xf4\x99\xf4\xac\x91\xc0\xae\xfbZ\x02u\x0fe*L\xa4\xf2W-\xe3\x98\xb8\xf0\xad5\x9cZ\xc2G\xd6\xb3\xfe\xd7\xe3\xd4\x87\xd6}\x99\xe2\xf03s\xf1\x9a\x1fL8\xe4\x18K\xdf\x99\x05`\x8cL\x85@\x1aE\xf8fb\xe0\x91\'q2\x7f}\xeb\xcarj\xa7\xe25\xc9\'\xac}\xfb\xab\x82\xed\xc4\xfc)\xbc\x80 \xc02\xe6\x84\xa90\xa1\xe5\xe7\x1b\xd4M3\xa8\xa9&\x06\x95&\xc3\x9c\xcd\xc7\x87\x0f\xc4WI*Q\x80\x9e\x1f\x8dM\x85l\t\xd29\xdf\x9e\xc4\x81A\xb1A\xdc=d\x81\x88_\x04\xc1\x94\xa5\n'
# b'\xd2\xa3!\x066\x9d\xb7\xde\xdc\xaa\x9b\x0e\x96\xf5\xado\xa5n\xb8\xff\x00vB[\xd2\n'
# b'])m\xc5\x9bq\xabA\xb4\xe9\xdb\xccT\xcd\xe2n\x92\x0c\xe9#\xde?\x9a\x8f7k\x87Rd\xfeb\x97\xa3P\xd1\xa8\xf4\x91i\x93\xf1\xa1[^p~%\xea\xb0\x0c\xa9\xf3\x0b`1\xaa\xfcK\xef)\x1aB\xbb\xb2\xd9\x8e\x19)\xe3\t\xe9}\xe8\x7fls\x0e\xf5A24\x17C\x80_P=\xda\xd3\xbc\xdc\x18\x06#\x95T\xc00P\x99M\x8a\x82uM\xf6\x16\x8b@\xb7J\xa0\xf6\x14\xea\xdeeS\xe4$\xfb\xcd\xd5\x7f\x18\xe4k\xb8\x82\x06\xa4)!\x89\xcc1\xd9\xe4\xa9\xa4\xfb\r:\x87.\xe3jP:\xb4\x82\xa4\xf0\xe9\xe1P\x12A\xd5\xaa\xe6\x00\x9a\xbd\x93:\x02\xbf\xb6\xfb\r\xb7\xeb\xd3\xce\x836\x1al\xdc\x95\x1b\xaaD\x80\t\xf5\xbfK\x8a\x9f\x04\xe0\x91\xa4\xefDD\x0b\x99G%\x84h\xcd1GY;M\xbet\xbd\x9e\x15-\xa4\xa4_\x8e\xfc\xf7\xd8\xf9\xd8\x8fZ$\x04\x81\xb9\xfb\xbf\xca\xba}\xa0\x00F\xda\xa5D\xce\xc5"\xd6\xe9\x7f\x85_\x88\xc6 \x14\xe1\xb3\x10_h\xa2S\x17\x93\xfc\xfc\xaa\xe6\x1f\x00\xb7\x8c\xb6S%0B\x94\x11\xd3b\xa8\x1c\xb9\x9eU> 52L\x90ox\x11\xfb\xfd\xde\xad\xb5\x8bm+\x84\'a\xf4\xde\x80k\x9a\x02\xdf\x89T\xe3\x14\xdb\x88\x1cd\x01%\'yPH]\x816%\xb4\x9fy\xebN\x9d\x80\xcd\xc3=\xe2\x1f\xef\x00Q\n'
# b"J\x88\xe1\x02:\x0b\xdc\x98\xb7\xf6\xa6\x94\xf0\xb9\x90J\xf0\xed\xaf\xd8C\x8a\x85\x1d\xc2VS\xacOA\xa8\xaa:\x93Z\xb670\xc2\xe5\xc8S\x98\x85$j\x16H\x12\xb5\xe9\xbc%<\xc7\xc3\xc6\x94\xb3\x00`\xc6\x90\xe7\xb46\xdbAPE\xc1\xb8#\x9f\xefUs%0\xd0\x97\\B?\xd4@'\xc8n}+1\xedG\xf5m\xc7\x11\xa7\x02\xd3\xac\x92x\x9dp \x90:%\x1cB|I\xb4my\x08xlC\xcf\xa8\xa9K+V\xe5J1\xe7\x7f\xd4\xa3\xd4\xfc\xb6_\xd3c\x19[\x02\xcd{6\xed#(I-\xa0\xb8\x93\x1cJ:\x12'\xc0\xf1{\xc0\xf3\xa4\xcc\xdf\xb5.\xb8\xefv\x95\xf7c`\x04\xa4\x1d\xe4\xda\xe7\x9d\x8a\xab\x8cF\x05?\x86Is\x9e\xe9I$u\x1b\xf8s\xa1\x98gp\xc8R\x88\xd4\xb8L\x8dJ*#\xf6\xb9\xf8T\x1e\x9f0\xc9\xd5\x91+f\xc3\xb8\x1f\xf55(\x9e!\xb0\x12$\x18\x1e6\xbc\x9bPT8\xa7L\xc91\xb0'\xdf\x03\x90\x88\xb5\x13\xcd\x9dJ\xd1a\xb9\xd4:\x91@\t\xd3\xc4\x93\x07\xa01U\x15`Bz\xdc\x8ec\xae[\x97\x86\xd0\x97\t\tY\xbf\x10\x9d\xb7)\x06\n"
# b"\x8c\xdb\xc3\xe2|r\xa2\xe2\x94\xb0\x00AQ$\xa9[\xea\x99\xbd\xc9\x80c\xf6\xa5\x86s\xa7\xc8\xd1&\xff\x00/\xa5\xc6\xdbQ6q\xcf '\xbe$\xdbm\x88\x06\xff\x00\xa7\xe5A5\x90s\x0c\x1c\x1e\xd2\x1c\xcf\x07\x86iJ\t\x95\xa8D\xc6\xc3\xd3\xac\xd0\x17\x85\xa6\xc3\x90\x1c\xef\xf0\xa38\xbcF\xa1)kJy\xfe\xf6\xb5\x07\xc5i\x17\xbc\xf4\xbd\\v\x9cD\x1aMY\xc1\xe0\x9cp\xc3h*>\x03\xc3\x9fJ\xbf\x94\xa1\txknRO\xea\xb8\xeb\xb7\x94\xc4\xd3\xea\xf8 $\x00:\x01\x03\xc6\xc2\x85e\xdct\x04?M\xd1z\xa0\x92\xd8\xc4OOc])\x9dh\n"
# b"\xfe\xd3=\t\xdcH\xde(\xa6_\xd9\x87?\x0e\x8d)J^\x0e\x15\x15j \x80v\x01I\xe64\xa4\xfa\x9b\xd1\xed|B\xf5l?\xa4xO*\x17\xa8\xc7\xbcs\xff\x00\x92\x95\xed\x02\xe2\xb18\xf7p\xae\xe1\xdeaJP(\tp\x14\x82HZW\xc4&\x16\x00\x1e\xda\x7fr\x18\xf18\xbe#\x1f\xbdT^k\xc8\xed\xd2\xa89\x98\xa0\x1a\xab{\xbcBT\xa13\xbc\xff\x00?\xeeE\x84z@\xd8\xda\xd3Cs$I3j\xf5z\xbd6}\xb3\xc0v3\x9c\x13\x9a`\x82\x0163\xb4EhY3`\x04\x10G\x10\x13\x1bu5\xea\xf5Y\x0e\xa2\xfd@\xeca\x9cN,i\xb6\xf4\x99\xdb\x06\xb5\xa4*\xd2'\xfe+\xd5\xea\xb0P\x04\x02\xb9k\x01\x8a\x89p\x01\x15\xf5\xb7y\xfd\xda\xbd^\xa1\x971\xe0\xa2\x14\xc3b\x05\x8d\xbc\xaa\x0cF$\x05X\x8b\x8f\xb3\xf2\xafW\xab\x99\xc9\x13\x82\x00el>:9\xc7:\xb6\xce,\x18\x9e\xb2/n\xbf\xb7\xbe\xbd^\xaa\xf22\xc5Fatc\x12\x00\x07}\xeb\xeb\xaf\xa6$\x113\x7f\n"
# b"\xf5z\xae\x8ceY\x04\x06\xff\x00\xb4o&\xfeu\x0bJRH7\x1d<'\xc2\xbd^\xae&X\x08\xc1\x97bTA\x13t\xfdw\xf9P\xee\xd2b;\xb8\x95\x10\xa2\x9f\x03\xb96\xb7\x97\x8dz\xbdVf!s!\x14s\xc4W\xc5\xe2\x92\xbf\xd5\xc5\xd0m]a1\xcb\x04\x00\x91&\xd2g\xe9_+\xd4\xb8$\xc7J\x05\x10\x86\x1b\x0e\xe3\xab\x1d\xe91\xb5\x8c}\xed_1\xb9\\J\x9cY'y7'\xa4\xaa\xe4\xd7\xab\xd5f\x1a\x82\x0cs8Nf\xce\x80\x8d\x07\x84\x99Uu\xd9\xe6\xc3\xaf\x84\x85i\x1b\xc7\x95\xeb\xedz\x97\x8c\x11\x80q\x19\xb3\xbcr\x12\xae\xecY\x00i!^_\xcd-?\x96\xdfSJ\n"
# b"\xbd\xc5z\xbd]\x99\t&9c\x8bM\x84D[\xcf\xd7\xe5S\xb1\xd9\x90[\xe8\xe03?J\xf5z\x93\xb9\xc8\xed4:u\x07\xbc\xa0\xefu\x87PY\x95(r\x8f\xae\xd5\xc6;<\x0f%GF\x93\xcb\xca+\xe5z\x8662cGG\x02\x04\xc3c\x15q\xb8\xaf\xae?\xab{\xfd\xf4\xafW\xaaL\x85'\x13\x82\n"
# b'\x80T\x18\x16\x04\x0e~\xbb\xed\xb8\xda\x9dr\xfc\xdd\x0ba*\xbc\xa6\x12\xa9\xdeBG>`\xf5>5\xea\xf5\x05\xd4\x18\xc7N\xc5_^D\x97\x0b\x89S\x86\xc2:\x1eQDJf\xd3^\xafP\x9bFh)\xc8\x83\xd6\xd8\x06\r\n'
# b'\xc4\xac\x05\x11\x15\xf2\xbdD\xacf\x06\xd3\x8e\xd3\xff\xd9'

# %% [markdown]
# Syntax: <font color="orange" face="courier new"><i>fileobj= open( filename, mode)</i></font>
# <br>
# <br>
# <ul>
#     <li><font color="orange" face="courier new">fileobj</font>: is the file object returned by <font color="orange" face="courier new">open()</font></li>
#     <li><font color="orange" face="courier new">filename</font>: String name of the  file</li>
#     <li><font color="orange" face="courier new">mode</font> is a string indicating the file's type and what do you want do with it.</li>
# </ul>
# <br>
# <br>
# The second letter of <font color="orange" face="courier new">mode</font> is the file's type:
# <ul>
#     <li><font color="orange" face="courier new">t</font>(or nothing) means text.</li>
#      <li><font color="orange" face="courier new">b</font> means binary.</li>
# </ul>
# <br><br>

# %%
#example 1
try:
    file=open('file1.txt','r')
    file.close()#free the memory
except FileNotFoundError:
    print("file does not exist")
# Out:
# file does not exist

# %% [markdown]
# ## Methods of File Objects

# %% [markdown]
# ### Write a Text File with <font color="orange" face="courier new"><i>print()</i></font>

# %%
#example 2
file=open('file1.txt','wt')
print('file 1 was created',file=file, end=" ")
file.close()

# %% [markdown]
# ### Write a Text File with <font color="orange" face="courier new"><i>write()</i></font>

# %%
#example 3
poem = '''There was a young lady named Bright,
... Whose speed was far faster than light;
... She started one day
... In a relative way,
... And returned on the previous night.'''
len(poem)
file=open('file1.txt','wt')
print(poem,file=file)
file.close()

# %%
#example 4

len(poem)
file=open('file2.txt','wt')
file.write(poem)
file.close()

# %% [markdown]
# If you have a large source string, you can also write chunks (using slices) until the source is done:

# %%
#exampl 5
f = open('file3.txt', 'wt')
size = len(poem)
offset = 0
chunk = 100
while True:
    if offset > size:
        break
    f.write(poem[offset:offset+chunk])
    offset += chunk
f.close()

# %%
#example 6
f1=open('file5.txt','xt')

# %%
#example 7
try:
    f1=open('file1.txt','xt')
    f1.write("Hi how are you ?")
except FileExistsError:
    print("File already exists")
# Out:
# File already exists

# %% [markdown]
# ### Read a Text File with <font color="orange" face="courier new"><i>read()</i></font>,<font color="orange" face="courier new"><i>readline()</i></font>, or <font color="orange" face="courier new"><i>readlines()</i></font>
# <br>
# <font color="orange" face="courier new"><i>read(size)</i></font>: reads some quantity of data and returns it as a string (in text mode) or bytes object(in binary mode). <font color="orange" face="courier new"><i>size</i></font> is an optional numeric argument. When <font color="orange" face="courier new"><i>size</i></font> is omitted or negative, the entire contents of the file will be read and returned. it’s our problem if the file is twice as large as your machine’s memory. If the end of the file has been reached, <font color="orange" face="courier new"><i>read()</i></font> will return an empty string ('').<br>
# Usage:<font color="orange" face="courier new"><i>fileobject.read([size])</i></font>

# %%
#example 8: read data from the file
f=open('file1.txt','rt')
poem=f.read()
f.close()
print(len(poem))
print(poem)
# Out:
# 167
# There was a young lady named Bright,
# ... Whose speed was far faster than light;
# ... She started one day
# ... In a relative way,
# ... And returned on the previous night.

# %%
#example 9: read n characteres at a time.
poem=''
f1=open('file2.txt','rt')
chunk=100
while True:
    fragment=f1.read(chunk)
    if not fragment:
        break
    poem+=fragment
f1.close()
print(len(poem))
print(poem)

# %%
#example 10: readline example
poem=''
f2=open('file2.txt','rt')
for line in f2:
    poem+=line
f2.close()
len(poem)
# Out:
# 166

# %% [markdown]
# <ul>
#     <li><font color="orange" face="courier new"><i>f.readline()</i></font> reads a single line from the file; a newline character (\n) is left at the end of the string, and is only omitted on the last line of the file if the file doesn’t end in a newline.</li>
#     <li> if <font color="orange" face="courier new"><i>f.readline()</i></font> returns an empty string, the end of the file has been reached</li>
#     <li>A blank line is represented by <i>'\n'</i>, a string containing only a single newline</li>
# </ul>

# %%
file=open('file1.txt')
file.readline()
# Out:
# 'There was a young lady named Bright,\n'

# %%
file.readline()
# Out:
# '... Whose speed was far faster than light;\n'

# %% [markdown]
# If you want to read all the lines of a file in a list you can also use <font color="orange" face="courier new"><i>list(f) </i></font>  or <font color="orange" face="courier new"><i>f.readlines()</i></font> .

# %%
#example 11: readlines example
f3=open('file3.txt','rt')
lines=f3.readlines()
f3.close()
print(len(lines))
for line in lines:
    print(line)
# Out:
# 5
# There was a young lady named Bright,
#
# ... Whose speed was far faster than light;
#
# ... She started one day
#
# ... In a relative way,
#
# ... And returned on the previous night.

# %% [markdown]
# ### Write a binary file with <font color="orange" face="courier new"><i>write()</i></font>

# %%
bdata = bytes(range(0, 256))
len(bdata)
f = open('bfile1', 'wb')
f.write(bdata)
f.close()

# %%
f=open('bfile1','rb')
print(f.read())
f.close
# Out:
# b'\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a\x1b\x1c\x1d\x1e\x1f !"#$%&\'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~'
# <function BufferedReader.close>

# %%
fout = open('bfile2', 'wb')
size = len(bdata)
offset = 0
chunk = 100
while True:
    if offset > size:
        break
    fout.write(bdata[offset:offset+chunk])
    offset += chunk

# %% [markdown]
# ###  Task 1: Write a program that reads a binary file

# %% [markdown]
# ### Close Files Automatically by Using <font color="orange" face="courier new"><i>with</i></font>

# %% [markdown]
# <ul>
#     <li>It is good practice to use the <font color="orange" face="courier new"><i>with </i></font> keyword when dealing with file objects.</li>
#     <li>The advantage is that the file is properly closed after its suite finishes, even if an exception is raised at some point.</li>
#     <li> Using <font color="orange" face="courier new"><i>with </i></font> is also much shorter than writing equivalent <font color="orange" face="courier new"><i> try-finally </i></font> blocks</li>
#     </ul>

# %%
with open('file1.txt', 'r') as f:
    print(f.read())
# Out:
# There was a young lady named Bright,
# ... Whose speed was far faster than light;
# ... She started one day
# ... In a relative way,
# ... And returned on the previous night.

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-571e9fb02258> in <module>
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ### <font color="orange" face="courier new"><i>f.seek(offset, whence)</i></font>: change the file object’s position

# %% [markdown]
# <ul>
# <li>The position is computed from adding <font color="orange" face="courier new"><i> offset</i></font> to a reference point; the reference point is selected by the <font color="orange" face="courier new"><i>whence</i></font> argument.</li>
#  <li> <font color="orange" face="courier new"><i>whence</i></font> value of:<ul>
#      <li>0 measures from the beginning of the file</li>
#      <li>1 uses the current file position</li>
#      <li>2 uses the end of the file as the reference point.</li>
#     </ul>
#      <li><font color="orange" face="courier new"><i>whence</i></font> can be omitted and defaults to 0, using the beginning of the file as the reference point.</li>
#     </ul>

# %%
f = open('workfile', 'rb+')
f.write(b'0123456789abcdef') #16
f.seek(5)      # Go to the 6th byte in the file
f.read(1) #b'5'

# %% [markdown]
# # Reading json data

# %% [markdown]
# <ul>
# <li>The standard module called json can take Python data hierarchies, and convert them to string representations; this process is called <i>serializing</i>.</li>
#   <li>  Reconstructing the data from the string representation is called <i>deserializing</i>.</li>
#    <li> Between <i>serializing</i> and <i>deserializing </i>, the string representing the object may have been stored in a file or data, or sent over a network connection to some distant machine.</li>
#     <li>The JSON format is commonly used by modern applications to allow for data exchange. Many programmers are already familiar with it, which makes it a good choice for interoperability.</li>
#     <li>Functions <font color="orange" face="courier new"><i>dumps()</i></font>, and <font color="orange" face="courier new"><i>dump()</i></font> simply serializes the object to a text file.
# </ul>

# %% [markdown]
# Syntax: <br>
# <font color="orange" face="courier new"><i>
#     json.dump(obj, fp, *, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, cls=None, indent=None, separators=None, default=None, sort_keys=False, **kw)</i></font>
#     <br>
#     <p>Serialize obj as a JSON formatted stream to fp (a .write()-supporting file-like object) using this conversion table.</p>
#     <table border='1.0 px'>
#     <tr><th>Python</th><th>json</th> </tr>
#     <tr><td>dict</td><td>object</td></tr>
#     <tr><td>list,tuple</td><td>array</td></tr>
#     <tr><td>str</td><td>string</td></tr>
#     <tr><td>int, float, int- & float-derived Enums</td><td>number</td></tr>
#     <tr><td>True</td><td>true</td></tr>
#     <tr><td>False</td><td>false</td></tr>
#     <tr><td>None</td><td>null</td></tr>
#     </table><br><br>
#     <p>If you want to dump the JSON into a file/socket or whatever, then you should go for <font color="orange" face="courier new"><i>dump()</i></font>. If you only need it as a string (for printing, parsing or whatever) then use <font color="orange" face="courier new"><i>dumps()</i></font> (dump string)</p>
#     syntax: <br><font color="orange" face="courier new"><i>
#     json.dumps(obj, *, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, cls=None, indent=None, separators=None, default=None, sort_keys=False, **kw)</i></font>

# %%
import json
a=[1, 'simple', 'list']
print(a)
json.dumps(a)
# Out:
# [1, 'simple', 'list']
# '[1, "simple", "list"]'

# %%
import json

data = {}
data['prog'] = []
data['prog'].append({
    'name': 'python',
    'website': 'python.org',
    'version': 3.8
})
data['prog'].append({
    'name': 'php',
    'website': 'php.org',
    'version': 7.2
})
data['prog'].append({
    'name': 'java',
    'website': 'oracle.com',
    'from': 1.8
})
print(data)
with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)
# Out:
# {'prog': [{'name': 'python', 'website': 'python.org', 'version': 3.8}, {'name': 'php', 'website': 'php.org', 'version': 7.2}, {'name': 'java', 'website': 'oracle.com', 'from': 1.8}]}

# %% [markdown]
# <font color="orange" face="courier new"><i>json.load(<filename>)</i></font>: To decode the object again

# %%
with open('data.txt', 'r') as outfile:
    data=json.load(outfile)
data
# Out:
# {'prog': [{'name': 'python', 'website': 'python.org', 'version': 3.8},
#   {'name': 'php', 'website': 'php.org', 'version': 7.2},
#   {'name': 'java', 'website': 'oracle.com', 'from': 1.8}]}
